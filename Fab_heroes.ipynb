# %%
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import requests
import requests
import os
from datetime import datetime
from utils import *

# %%
classes = ['Guardian', "Warrior", "Runeblade", "Mechanologist", "Ninja", "Adjudicator", "Necromancer", "Bard", "Shapeshifter", "Thief", "Brute", "Assassin", "Wizard", "Illusionist", "Ranger", "Pirate", "Merchant", "Pit-Fighter", "cleric"]
talents = ["Elemental" ,"Draconic","Mystic","Light","Shadow","Royal","Reviled","Revered","Chaos"]

# %%
ARQUIVO = 'heroes_fabtcg.csv'
url = 'https://cards.fabtcg.com/api/search/v1/cards/?type=Hero&offset=0&limit=99999'

if arquivo_e_atual(ARQUIVO):
    print("O arquivo esta atualizado.")
else:
    print("O arquivo não existe ou esta desatualizado, corrigindo.")
    
    apagar_arquivo(ARQUIVO)
    
    session = requests.Session()
    session.headers.update(headers)
    
    response = session.get(url)
    response.raise_for_status()

    dados = response.json()
    
    # 1. Ver quais são as chaves principais
    print("Chaves principais:", dados.keys())
    
    lista_cartas = dados.get('data', dados.get('results', dados))
    dict_cartas = {}
    for carta in lista_cartas:
    
        nome_indice = carta["name"]
    
        dict_cartas[nome_indice] = {"tipo" : carta["typebox"].split() }
    
        #remove '-' e 'Hero"
        if "-" in dict_cartas[nome_indice]["tipo"]:
            dict_cartas[nome_indice]["tipo"].remove("-")
        if "Hero" in dict_cartas[nome_indice]["tipo"]:
            dict_cartas[nome_indice]["tipo"].remove("Hero")
    

    dict_final = dict_cartas
    for hero in dict_final:
        dict_final[hero]["Classe"] = []
        dict_final[hero]["Talento"] = []
        dict_final[hero]["Idade"] = []
        dict_final[hero]["Heroi"] = str(hero)
        for item in dict_final[hero]["tipo"]:
            if item in classes:
                dict_final[hero]["Classe"].append(item)
            if item in talents:
                dict_final[hero]["Talento"].append(item)
            if item == "Young":
                dict_final[hero]["Idade"] = [item]
            if "Young" not in dict_final[hero]["Idade"]:
                dict_final[hero]["Idade"] = ["Adult"]
            if len(dict_final[hero]["Talento"]) == 0:
                dict_final[hero]["Talento"] = ["nenhum"]
            if item not in classes and item not in talents and item != "Young":
                print("-----------------------POSSIVEL NOVO TALENTO/CLASSE OU ERRO-----------------------")

        del dict_final[hero]["tipo"]
    
    df = pd.DataFrame(dict_final)
    df = df.T
    
    
    # Salva para a próxima vez
    df.to_csv(ARQUIVO, index=False)
    print("Dados salvos localmente!")
# Out:
# O arquivo esta atualizado.

# %%
dict_final
# Out:
# {'Arakni': {'Classe': ['Assassin'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Arakni'},
#  'Arakni, 5L!p3d 7hRu 7h3 cR4X': {'Classe': ['Assassin'],
#   'Talento': ['Chaos'],
#   'Idade': ['Adult'],
#   'Heroi': 'Arakni, 5L!p3d 7hRu 7h3 cR4X'},
#  'Arakni, Huntsman': {'Classe': ['Assassin'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Arakni, Huntsman'},
#  'Arakni, Marionette': {'Classe': ['Assassin'],
#   'Talento': ['Chaos'],
#   'Idade': ['Adult'],
#   'Heroi': 'Arakni, Marionette'},
#  'Arakni, Solitary Confinement': {'Classe': ['Assassin'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Arakni, Solitary Confinement'},
#  'Arakni, Web of Deceit': {'Classe': ['Assassin'],
#   'Talento': ['Chaos'],
#   'Idade': ['Young'],
#   'Heroi': 'Arakni, Web of Deceit'},
#  'Aurora': {'Classe': ['Runeblade'],
#   'Talento': ['Elemental'],
#   'Idade': ['Young'],
#   'Heroi': 'Aurora'},
#  'Aurora, Shooting Star': {'Classe': ['Runeblade'],
#   'Talento': ['Elemental'],
#   'Idade': ['Adult'],
#   'Heroi': 'Aurora, Shooting Star'},
#  'Azalea': {'Classe': ['Ranger'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Azalea'},
#  'Azalea, Ace in the Hole': {'Classe': ['Ranger'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Azalea, Ace in the Hole'},
#  'Benji, the Piercing Wind': {'Classe': ['Ninja'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Benji, the Piercing Wind'},
#  'Betsy': {'Classe': ['Guardian'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Betsy'},
#  'Betsy, Skin in the Game': {'Classe': ['Guardian'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Betsy, Skin in the Game'},
#  'Blaze, Firemind': {'Classe': ['Wizard'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Blaze, Firemind'},
#  'Bolfar, Bear Hands': {'Classe': ['Guardian', 'Pit-Fighter'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Bolfar, Bear Hands'},
#  'Boltyn': {'Classe': ['Warrior'],
#   'Talento': ['Light'],
#   'Idade': ['Young'],
#   'Heroi': 'Boltyn'},
#  'Bravo': {'Classe': ['Guardian'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Bravo'},
#  'Bravo, Flattering Showman': {'Classe': ['Guardian'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Bravo, Flattering Showman'},
#  'Bravo, Showstopper': {'Classe': ['Guardian'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Bravo, Showstopper'},
#  'Bravo, Star of the Show': {'Classe': ['Guardian'],
#   'Talento': ['Elemental'],
#   'Idade': ['Adult'],
#   'Heroi': 'Bravo, Star of the Show'},
#  'Brevant, Civic Protector': {'Classe': ['Guardian'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Brevant, Civic Protector'},
#  'Briar': {'Classe': ['Runeblade'],
#   'Talento': ['Elemental'],
#   'Idade': ['Young'],
#   'Heroi': 'Briar'},
#  'Briar, Warden of Thorns': {'Classe': ['Runeblade'],
#   'Talento': ['Elemental'],
#   'Idade': ['Adult'],
#   'Heroi': 'Briar, Warden of Thorns'},
#  'Brutus, Summa Rudis': {'Classe': ['Adjudicator'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Brutus, Summa Rudis'},
#  'Chane': {'Classe': ['Runeblade'],
#   'Talento': ['Shadow'],
#   'Idade': ['Young'],
#   'Heroi': 'Chane'},
#  'Chane, Bound by Shadow': {'Classe': ['Runeblade'],
#   'Talento': ['Shadow'],
#   'Idade': ['Adult'],
#   'Heroi': 'Chane, Bound by Shadow'},
#  'Cindra': {'Classe': ['Ninja'],
#   'Talento': ['Royal', 'Draconic'],
#   'Idade': ['Young'],
#   'Heroi': 'Cindra'},
#  'Cindra, Dracai of Retribution': {'Classe': ['Ninja'],
#   'Talento': ['Royal', 'Draconic'],
#   'Idade': ['Adult'],
#   'Heroi': 'Cindra, Dracai of Retribution'},
#  'Dash': {'Classe': ['Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Dash'},
#  'Dash, Database': {'Classe': ['Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Dash, Database'},
#  'Dash, Inventor Extraordinaire': {'Classe': ['Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Dash, Inventor Extraordinaire'},
#  'Dash I/O': {'Classe': ['Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Dash I/O'},
#  'Data Doll MKII': {'Classe': ['Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Data Doll MKII'},
#  'Dorinthea': {'Classe': ['Warrior'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Dorinthea'},
#  'Dorinthea Ironsong': {'Classe': ['Warrior'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Dorinthea Ironsong'},
#  'Dorinthea, Quicksilver Prodigy': {'Classe': ['Warrior'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Dorinthea, Quicksilver Prodigy'},
#  'Dromai': {'Classe': ['Illusionist'],
#   'Talento': ['Draconic'],
#   'Idade': ['Young'],
#   'Heroi': 'Dromai'},
#  'Dromai, Ash Artist': {'Classe': ['Illusionist'],
#   'Talento': ['Draconic'],
#   'Idade': ['Adult'],
#   'Heroi': 'Dromai, Ash Artist'},
#  'Emperor, Dracai of Aesir': {'Classe': ['Warrior', 'Wizard'],
#   'Talento': ['Royal', 'Draconic'],
#   'Idade': ['Young'],
#   'Heroi': 'Emperor, Dracai of Aesir'},
#  'Enigma': {'Classe': ['Illusionist'],
#   'Talento': ['Mystic'],
#   'Idade': ['Young'],
#   'Heroi': 'Enigma'},
#  'Enigma, Ledger of Ancestry': {'Classe': ['Illusionist'],
#   'Talento': ['Mystic'],
#   'Idade': ['Adult'],
#   'Heroi': 'Enigma, Ledger of Ancestry'},
#  'Enigma, New Moon': {'Classe': ['Illusionist'],
#   'Talento': ['Mystic'],
#   'Idade': ['Young'],
#   'Heroi': 'Enigma, New Moon'},
#  'Fai': {'Classe': ['Ninja'],
#   'Talento': ['Draconic'],
#   'Idade': ['Young'],
#   'Heroi': 'Fai'},
#  'Fai, Rising Rebellion': {'Classe': ['Ninja'],
#   'Talento': ['Draconic'],
#   'Idade': ['Adult'],
#   'Heroi': 'Fai, Rising Rebellion'},
#  'Fang': {'Classe': ['Warrior'],
#   'Talento': ['Royal', 'Draconic'],
#   'Idade': ['Young'],
#   'Heroi': 'Fang'},
#  'Fang, Dracai of Blades': {'Classe': ['Warrior'],
#   'Talento': ['Royal', 'Draconic'],
#   'Idade': ['Adult'],
#   'Heroi': 'Fang, Dracai of Blades'},
#  'Fightmaster Kox': {'Classe': ['Guardian', 'Pit-Fighter'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Fightmaster Kox'},
#  'Florian': {'Classe': ['Runeblade'],
#   'Talento': ['Elemental'],
#   'Idade': ['Young'],
#   'Heroi': 'Florian'},
#  'Florian, Rotwood Harbinger': {'Classe': ['Runeblade'],
#   'Talento': ['Elemental'],
#   'Idade': ['Adult'],
#   'Heroi': 'Florian, Rotwood Harbinger'},
#  'Genis Wotchuneed': {'Classe': ['Merchant'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Genis Wotchuneed'},
#  'Gravy Bones': {'Classe': ['Pirate', 'Necromancer'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Gravy Bones'},
#  'Gravy Bones, Shipwrecked Looter': {'Classe': ['Pirate', 'Necromancer'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Gravy Bones, Shipwrecked Looter'},
#  'Groundbreaker Crix': {'Classe': ['Guardian', 'Pit-Fighter'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Groundbreaker Crix'},
#  'Ira, Crimson Haze': {'Classe': ['Ninja'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Ira, Crimson Haze'},
#  'Ira, Scarlet Revenger': {'Classe': ['Ninja'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Ira, Scarlet Revenger'},
#  'Iyslander': {'Classe': ['Wizard'],
#   'Talento': ['Elemental'],
#   'Idade': ['Young'],
#   'Heroi': 'Iyslander'},
#  'Iyslander, Stormbind': {'Classe': ['Wizard'],
#   'Talento': ['Elemental'],
#   'Idade': ['Adult'],
#   'Heroi': 'Iyslander, Stormbind'},
#  'Jarl Vetreiði': {'Classe': ['Guardian'],
#   'Talento': ['Elemental'],
#   'Idade': ['Adult'],
#   'Heroi': 'Jarl Vetreiði'},
#  'Kano': {'Classe': ['Wizard'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Kano'},
#  'Kano, Dracai of Aether': {'Classe': ['Wizard'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Kano, Dracai of Aether'},
#  'Kassai': {'Classe': ['Warrior'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Kassai'},
#  'Kassai, Cintari Sellsword': {'Classe': ['Warrior'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Kassai, Cintari Sellsword'},
#  'Kassai of the Golden Sand': {'Classe': ['Warrior'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Kassai of the Golden Sand'},
#  'Katsu': {'Classe': ['Ninja'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Katsu'},
#  'Katsu, the Wanderer': {'Classe': ['Ninja'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Katsu, the Wanderer'},
#  'Kavdaen, Trader of Skins': {'Classe': ['Merchant'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Kavdaen, Trader of Skins'},
#  'Kayo': {'Classe': ['Brute'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Kayo'},
#  'Kayo, Armed and Dangerous': {'Classe': ['Brute'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Kayo, Armed and Dangerous'},
#  'Kayo, Berserker Runt': {'Classe': ['Brute'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Kayo, Berserker Runt'},
#  'Kayo, Strong-arm': {'Classe': ['Brute'],
#   'Talento': ['Reviled'],
#   'Idade': ['Young'],
#   'Heroi': 'Kayo, Strong-arm'},
#  'Kayo, Underhanded Cheat': {'Classe': ['Brute'],
#   'Talento': ['Reviled'],
#   'Idade': ['Adult'],
#   'Heroi': 'Kayo, Underhanded Cheat'},
#  'Levia': {'Classe': ['Brute'],
#   'Talento': ['Shadow'],
#   'Idade': ['Young'],
#   'Heroi': 'Levia'},
#  'Levia, Shadowborn Abomination': {'Classe': ['Brute'],
#   'Talento': ['Shadow'],
#   'Idade': ['Adult'],
#   'Heroi': 'Levia, Shadowborn Abomination'},
#  'Lexi': {'Classe': ['Ranger'],
#   'Talento': ['Elemental'],
#   'Idade': ['Young'],
#   'Heroi': 'Lexi'},
#  'Lexi, Livewire': {'Classe': ['Ranger'],
#   'Talento': ['Elemental'],
#   'Idade': ['Adult'],
#   'Heroi': 'Lexi, Livewire'},
#  'Lyath Goldmane': {'Classe': ['Guardian'],
#   'Talento': ['Reviled'],
#   'Idade': ['Young'],
#   'Heroi': 'Lyath Goldmane'},
#  'Lyath Goldmane, Vile Savant': {'Classe': ['Guardian'],
#   'Talento': ['Reviled'],
#   'Idade': ['Adult'],
#   'Heroi': 'Lyath Goldmane, Vile Savant'},
#  'Marlynn': {'Classe': ['Pirate', 'Ranger'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Marlynn'},
#  'Marlynn, Treasure Hunter': {'Classe': ['Pirate', 'Ranger'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Marlynn, Treasure Hunter'},
#  'Maxx Nitro': {'Classe': ['Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Maxx Nitro'},
#  "Maxx 'The Hype' Nitro": {'Classe': ['Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': "Maxx 'The Hype' Nitro"},
#  'Melody, Sing-along': {'Classe': ['Bard'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Melody, Sing-along'},
#  'Nuu': {'Classe': ['Assassin'],
#   'Talento': ['Mystic'],
#   'Idade': ['Young'],
#   'Heroi': 'Nuu'},
#  'Nuu, Alluring Desire': {'Classe': ['Assassin'],
#   'Talento': ['Mystic'],
#   'Idade': ['Adult'],
#   'Heroi': 'Nuu, Alluring Desire'},
#  'Oldhim': {'Classe': ['Guardian'],
#   'Talento': ['Elemental'],
#   'Idade': ['Young'],
#   'Heroi': 'Oldhim'},
#  'Oldhim, Grandfather of Eternity': {'Classe': ['Guardian'],
#   'Talento': ['Elemental'],
#   'Idade': ['Adult'],
#   'Heroi': 'Oldhim, Grandfather of Eternity'},
#  'Olympia': {'Classe': ['Warrior'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Olympia'},
#  'Olympia, Prized Fighter': {'Classe': ['Warrior'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Olympia, Prized Fighter'},
#  'Oscilio': {'Classe': ['Wizard'],
#   'Talento': ['Elemental'],
#   'Idade': ['Young'],
#   'Heroi': 'Oscilio'},
#  'Oscilio, Constella Intelligence': {'Classe': ['Wizard'],
#   'Talento': ['Elemental'],
#   'Idade': ['Adult'],
#   'Heroi': 'Oscilio, Constella Intelligence'},
#  'Pleiades': {'Classe': ['Guardian'],
#   'Talento': ['Revered'],
#   'Idade': ['Young'],
#   'Heroi': 'Pleiades'},
#  'Pleiades, Superstar': {'Classe': ['Guardian'],
#   'Talento': ['Revered'],
#   'Idade': ['Adult'],
#   'Heroi': 'Pleiades, Superstar'},
#  'Prism': {'Classe': ['Illusionist'],
#   'Talento': ['Light'],
#   'Idade': ['Young'],
#   'Heroi': 'Prism'},
#  'Prism, Advent of Thrones': {'Classe': ['Illusionist'],
#   'Talento': ['Light'],
#   'Idade': ['Young'],
#   'Heroi': 'Prism, Advent of Thrones'},
#  'Prism, Awakener of Sol': {'Classe': ['Illusionist'],
#   'Talento': ['Light'],
#   'Idade': ['Adult'],
#   'Heroi': 'Prism, Awakener of Sol'},
#  'Prism, Sculptor of Arc Light': {'Classe': ['Illusionist'],
#   'Talento': ['Light'],
#   'Idade': ['Adult'],
#   'Heroi': 'Prism, Sculptor of Arc Light'},
#  'Professor Teklovossen': {'Classe': ['Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Professor Teklovossen'},
#  'Puffin': {'Classe': ['Pirate', 'Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Puffin'},
#  'Puffin, Hightail': {'Classe': ['Pirate', 'Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Puffin, Hightail'},
#  'Reya, the Unyielding': {'Classe': ['Guardian', 'Pit-Fighter'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Reya, the Unyielding'},
#  'Rhinar': {'Classe': ['Brute'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Rhinar'},
#  'Rhinar, Reckless Rampage': {'Classe': ['Brute'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Rhinar, Reckless Rampage'},
#  'Riptide': {'Classe': ['Ranger'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Riptide'},
#  'Riptide, Lurker of the Deep': {'Classe': ['Ranger'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Riptide, Lurker of the Deep'},
#  "Ruu'di, Gem Keeper": {'Classe': ['Merchant'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': "Ruu'di, Gem Keeper"},
#  'Scurv, Stowaway': {'Classe': ['Pirate', 'Thief'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Scurv, Stowaway'},
#  'Ser Boltyn, Breaker of Dawn': {'Classe': ['Warrior'],
#   'Talento': ['Light'],
#   'Idade': ['Adult'],
#   'Heroi': 'Ser Boltyn, Breaker of Dawn'},
#  'Shiyana, Diamond Gemini': {'Classe': ['Shapeshifter'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Shiyana, Diamond Gemini'},
#  'Squizzy & Floof': {'Classe': ['Merchant'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Squizzy & Floof'},
#  'Taipanis, Dracai of Judgement': {'Classe': ['Adjudicator'],
#   'Talento': ['Draconic'],
#   'Idade': ['Adult'],
#   'Heroi': 'Taipanis, Dracai of Judgement'},
#  'Taylor': {'Classe': ['Shapeshifter'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Taylor'},
#  'Teklovossen': {'Classe': ['Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Teklovossen'},
#  'Teklovossen, Esteemed Magnate': {'Classe': ['Mechanologist'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Teklovossen, Esteemed Magnate'},
#  'Terra': {'Classe': ['Guardian'],
#   'Talento': ['Elemental'],
#   'Idade': ['Young'],
#   'Heroi': 'Terra'},
#  'Theryon, Magister of Justice': {'Classe': ['Adjudicator'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Theryon, Magister of Justice'},
#  'Tuffnut': {'Classe': ['Brute'],
#   'Talento': ['Revered'],
#   'Idade': ['Young'],
#   'Heroi': 'Tuffnut'},
#  'Tuffnut, Bumbling Hulkster': {'Classe': ['Brute'],
#   'Talento': ['Revered'],
#   'Idade': ['Adult'],
#   'Heroi': 'Tuffnut, Bumbling Hulkster'},
#  'Uzuri': {'Classe': ['Assassin'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Uzuri'},
#  'Uzuri, Switchblade': {'Classe': ['Assassin'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Uzuri, Switchblade'},
#  'Valda Brightaxe': {'Classe': ['Guardian'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Valda Brightaxe'},
#  'Valda, Seismic Impact': {'Classe': ['Guardian'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Valda, Seismic Impact'},
#  'Verdance': {'Classe': ['Wizard'],
#   'Talento': ['Elemental'],
#   'Idade': ['Young'],
#   'Heroi': 'Verdance'},
#  'Verdance, Thorn of the Rose': {'Classe': ['Wizard'],
#   'Talento': ['Elemental'],
#   'Idade': ['Adult'],
#   'Heroi': 'Verdance, Thorn of the Rose'},
#  'Victor Goldmane': {'Classe': ['Guardian'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Victor Goldmane'},
#  'Victor Goldmane, High and Mighty': {'Classe': ['Guardian'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Victor Goldmane, High and Mighty'},
#  'Victor Goldmane, Match Fixer': {'Classe': ['Guardian', 'Pit-Fighter'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Victor Goldmane, Match Fixer'},
#  'Viserai': {'Classe': ['Runeblade'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Viserai'},
#  'Viserai, Rune Blood': {'Classe': ['Runeblade'],
#   'Talento': ['nenhum'],
#   'Idade': ['Adult'],
#   'Heroi': 'Viserai, Rune Blood'},
#  'Vynnset': {'Classe': ['Runeblade'],
#   'Talento': ['Shadow'],
#   'Idade': ['Young'],
#   'Heroi': 'Vynnset'},
#  'Vynnset, Iron Maiden': {'Classe': ['Runeblade'],
#   'Talento': ['Shadow'],
#   'Idade': ['Adult'],
#   'Heroi': 'Vynnset, Iron Maiden'},
#  'Yoji, Royal Protector': {'Classe': ['Guardian'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Yoji, Royal Protector'},
#  'Yorick, Weaver of Tales': {'Classe': ['Bard'],
#   'Talento': ['nenhum'],
#   'Idade': ['Young'],
#   'Heroi': 'Yorick, Weaver of Tales'},
#  'Zen': {'Classe': ['Ninja'],
#   'Talento': ['Mystic'],
#   'Idade': ['Young'],
#   'Heroi': 'Zen'},
#  'Zen, Tamer of Purpose': {'Classe': ['Ninja'],
#   'Talento': ['Mystic'],
#   'Idade': ['Adult'],
#   'Heroi': 'Zen, Tamer of Purpose'}}

# %%
df
# Out:
#                                    Classe   Talento    Idade  \
# Arakni                         [Assassin]  [nenhum]  [Young]
# Arakni, 5L!p3d 7hRu 7h3 cR4X   [Assassin]   [Chaos]  [Adult]
# Arakni, Huntsman               [Assassin]  [nenhum]  [Adult]
# Arakni, Marionette             [Assassin]   [Chaos]  [Adult]
# Arakni, Solitary Confinement   [Assassin]  [nenhum]  [Young]
# ...                                   ...       ...      ...
# Vynnset, Iron Maiden          [Runeblade]  [Shadow]  [Adult]
# Yoji, Royal Protector          [Guardian]  [nenhum]  [Young]
# Yorick, Weaver of Tales            [Bard]  [nenhum]  [Young]
# Zen                               [Ninja]  [Mystic]  [Young]
# Zen, Tamer of Purpose             [Ninja]  [Mystic]  [Adult]
#
#                                                      Heroi
# Arakni                                              Arakni
# Arakni, 5L!p3d 7hRu 7h3 cR4X  Arakni, 5L!p3d 7hRu 7h3 cR4X
# Arakni, Huntsman                          Arakni, Huntsman
# Arakni, Marionette                      Arakni, Marionette
# Arakni, Solitary Confinement  Arakni, Solitary Confinement
# ...                                                    ...
# Vynnset, Iron Maiden                  Vynnset, Iron Maiden
# Yoji, Royal Protector                Yoji, Royal Protector
# Yorick, Weaver of Tales            Yorick, Weaver of Tales
# Zen                                                    Zen
# Zen, Tamer of Purpose                Zen, Tamer of Purpose
#
# [134 rows x 4 columns]
